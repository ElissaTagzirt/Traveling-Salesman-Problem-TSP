# %%
pip install networkx numpy
# Out:
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.25.2)

# %%
import networkx as nx
import numpy as np
import random
import time
from networkx.algorithms.matching import min_weight_matching

# Build Graph first
import networkx as nx

def build_graph_from_distance_matrix(distance_matrix):
    G = nx.Graph()
    for i in range(len(distance_matrix)):
        for j in range(i + 1, len(distance_matrix)):
            G.add_edge(i, j, weight=distance_matrix[i][j])
    return G

## matrice de test :



def christofides_algorithm(G):
    # Trouver un arbre couvrant minimal
    T = nx.minimum_spanning_tree(G, weight='weight')

    # Trouver les sommets de degré impair dans l'arbre couvrant minimal
    odd_degree_nodes = [node for node in T.nodes() if T.degree(node) % 2 == 1]

    # Restreindre le graphe aux sommets de degré impair
    odd_graph = G.subgraph(odd_degree_nodes)

    # Trouver un matching parfait de poids minimum dans le graphe restreint
    matching = min_weight_matching(odd_graph)

    # Ajouter le matching à l'arbre couvrant minimal pour obtenir un multigraphe
    multigraph = nx.MultiGraph(T)
    for edge in matching:
        multigraph.add_edge(edge[0], edge[1], weight=G[edge[0]][edge[1]]['weight'])

    # Trouver un circuit Eulerien dans le multigraphe
    eulerian_circuit = list(nx.eulerian_circuit(multigraph))

    # Convertir le circuit Eulerien en un circuit Hamiltonien et calculer le coût
    visited = set()
    hamiltonian_circuit = []
    total_cost = 0
    last_node = None
    #print(eulerian_circuit)
    for u, v in eulerian_circuit:
        if u not in visited:
            if last_node is not None:
                total_cost += G[last_node][u]['weight']
            visited.add(u)
            hamiltonian_circuit.append(u)
            last_node = u
        if v not in visited:
            if last_node is not None:
                total_cost += G[last_node][v]['weight']
            visited.add(v)
            hamiltonian_circuit.append(v)
            last_node = v
    # Ajouter le coût pour retourner au point de départ
    # Ajouter le coût pour retourner au point de départ pour former un cycle
    if hamiltonian_circuit:
        start_node = hamiltonian_circuit[0]
        end_node = hamiltonian_circuit[-1]
        if start_node != end_node:
            hamiltonian_circuit.append(start_node)
            total_cost += G[end_node][start_node]['weight']

    return hamiltonian_circuit, total_cost

def tabu_search(G, initial_solution, initial_cost, num_iterations, initial_tabu_size, max_tabu_size):
    best_solution = initial_solution[:]
    best_cost = initial_cost
    tabu_list = []
    current_tabu_size = initial_tabu_size

    def adjust_tabu_size(iteration, best_cost_change):
        if best_cost_change == 0:
            return min(current_tabu_size + 1, max_tabu_size)
        return max(current_tabu_size - 1, initial_tabu_size)

    for iteration in range(num_iterations):
        # Create a new solution by swapping two random cities
        current_solution = best_solution[:]
        i, j = sorted(random.sample(range(len(best_solution)), 2))
        current_solution[i], current_solution[j] = current_solution[j], current_solution[i]

        # Calculate the total cost of the new solution
        current_cost = 0
        for idx in range(1, len(current_solution)):
            if (current_solution[idx-1], current_solution[idx]) in tabu_list:
                current_cost += G[current_solution[idx-1]][current_solution[idx]]['weight'] * 1.1  # Penalize moves in the tabu list by 10%
            else:
                current_cost += G[current_solution[idx-1]][current_solution[idx]]['weight']

        # Add cost of returning to the starting point to complete the cycle
        if (current_solution[-1], current_solution[0]) not in tabu_list:
            current_cost += G[current_solution[-1]][current_solution[0]]['weight']
        else:
            current_cost += G[current_solution[-1]][current_solution[0]]['weight'] * 1.1  # Penalize moves in the tabu list by 10%

        # If the new solution is better, update the best solution
        if current_cost < best_cost:
            best_solution, best_cost = current_solution, current_cost
            if (i, j) not in tabu_list:
                tabu_list.append((i, j))
                if len(tabu_list) > current_tabu_size:
                    tabu_list.pop(0)

        # Adjust the size of the tabu list based on recent changes in best cost
        current_tabu_size = adjust_tabu_size(iteration, best_cost - current_cost)

    return best_solution, best_cost



# Création d'un graphe complet avec des poids aléatoires pour les arêtes
G = build_graph_from_distance_matrix(matrix)
# Exécution de l'algorithme de Christofides
start_time = time.time()
initial_solution, initial_cost = christofides_algorithm(G)
christofides_time = time.time() - start_time
print(f"Christofides solution: {initial_solution}, Cost: {initial_cost}, Time: {christofides_time}s")

# Exécution de la recherche tabou
start_time = time.time()
best_solution, best_cost = tabu_search(G, initial_solution,initial_cost, 1000, 5, 10)
tabu_time = time.time() - start_time
print(f"Tabu Search best solution: {best_solution}, Cost: {best_cost}, Time: {tabu_time}s")
# Out:
# Christofides solution: [0, 1, 5, 9, 12, 11, 13, 14, 15, 10, 8, 6, 4, 2, 3, 7, 0], Cost: 255, Time: 0.004084110260009766s
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-95f4441cf873> in <cell line: 151>()
#     149 # Exécution de la recherche tabou
#     150 start_time = time.time()
# --> 151 best_solution, best_cost = tabu_search(G, initial_solution,initial_cost, 100, 5, 10)
#     152 tabu_time = time.time() - start_time
#     153 print(f"Tabu Search best solution: {best_solution}, Cost: {best_cost}, Time: {tabu_time}s")
#
# <ipython-input-10-95f4441cf873> in tabu_search(G, initial_solution, initial_cost, num_iterations, initial_tabu_size, max_tabu_size)
#     110         current_cost = 0
#     111         for idx in range(1, len(current_solution)):
# --> 112             weight = get_edge_weight(current_solution[idx-1], current_solution[idx])
#     113             if (current_solution[idx-1], current_solution[idx]) in tabu_list:
#     114                 current_cost += weight * 1.1  # Penalize moves in the tabu list by 10%
#
# <ipython-input-10-95f4441cf873> in get_edge_weight(u, v)
#      97             # Assuming there can be multiple edges, we take the minimum weight.
#      98             # This is common in cases like the Christofides algorithm where a multi-graph might be present.
# ---> 99             weight = min(G[u][v].values(), key=lambda x: x['weight'])['weight']
#     100             return weight
#     101         except KeyError:
#
# <ipython-input-10-95f4441cf873> in <lambda>(x)
#      97             # Assuming there can be multiple edges, we take the minimum weight.
#      98             # This is common in cases like the Christofides algorithm where a multi-graph might be present.
# ---> 99             weight = min(G[u][v].values(), key=lambda x: x['weight'])['weight']
#     100             return weight
#     101         except KeyError:
#
# TypeError: 'int' object is not subscriptable

# %%
import xml.etree.ElementTree as ET
import numpy as np

def load_xml_and_extract_matrix(xml_file_path):
    # Charger le fichier XML
    tree = ET.parse(xml_file_path)
    root = tree.getroot()

    # Trouver l'élément 'graph' qui contient les données de la matrice
    graph_element = root.find('graph')

    # Extraire la matrice symétrique
    return extract_symmetric_matrix(graph_element)

def extract_symmetric_matrix(graph_element):
    num_vertices = len(graph_element)  # Nombre de vertices (supposé carré)
    matrix = np.zeros((num_vertices, num_vertices), dtype=float)  # Initialiser la matrice de zéros

    # Parcourir chaque vertex
    for i, vertex in enumerate(graph_element):
        # Parcourir chaque edge du vertex
        for edge in vertex:
            j = int(edge.text) - 1  # Index du vertex connecté (base 1 à base 0)
            if i != j:  # Éviter de remplir la diagonale
                cost = float(edge.attrib['cost'])  # Coût de l'edge
                matrix[i, j] = cost
                matrix[j, i] = cost  # Assurer la symétrie

    return matrix

# Utiliser la fonction
file_path = '/content/gr24.xml'  # Remplacer par le chemin réel du fichier
matrice_distances = load_xml_and_extract_matrix(file_path)
print(matrice_distances)
# Out:
# [[  0. 187. 196. 228. 112. 196. 167. 154. 209.  86. 223. 191. 180.  83.
#    50. 219.  74. 139.  53.  43. 128.  99. 228. 142.]
#  [187.   0. 228. 158.  96.  88.  59.  63. 286. 124.  49. 121. 315. 172.
#   232.  92.  81.  98. 138. 200.  76.  89. 235.  99.]
#  [196. 228.   0.  96. 120.  77. 101. 105. 159. 156. 185.  27. 188. 149.
#   264.  82. 182. 261. 239. 232. 146. 221. 108.  84.]
#  [228. 158.  96.   0.  77.  63.  56.  34. 190.  40. 123.  83. 193.  79.
#   148. 119. 105. 144. 123.  98.  32. 105. 119.  35.]
#  [112.  96. 120.  77.   0.  56.  25.  29. 216. 124. 115.  47. 245. 139.
#   232.  31. 150. 176. 207. 200.  76. 189. 165.  29.]
#  [196.  88.  77.  63.  56.   0.  29.  22. 229.  95.  86.  64. 258. 134.
#   203.  43. 121. 164. 178. 171.  47. 160. 178.  42.]
#  [167.  59. 101.  56.  25.  29.   0. 229. 225.  82.  90.  68. 228. 112.
#   190.  58. 108. 136. 165. 131.  30. 147. 154.  36.]
#  [154.  63. 105.  34.  29.  22. 229.   0.  82. 207. 313. 173.  29. 126.
#   248. 238. 310. 389. 367. 166. 222. 349.  71. 220.]
#  [209. 286. 159. 190. 216. 229. 225.  82.   0. 313. 151. 119. 159.  62.
#   122. 147.  37. 116.  86.  90.  56.  76. 136.  70.]
#  [ 86. 124. 156.  40. 124.  95.  82. 207. 313.   0. 119. 148. 342. 199.
#   259.  84. 160. 147. 187. 227. 103. 138. 262. 126.]
#  [223.  49. 185. 123. 115.  86.  90. 313. 151. 119.   0. 342. 209. 153.
#   227.  53. 145. 224. 202. 195. 109. 184. 110.  55.]
#  [191. 121.  27.  83.  47.  64.  68. 173. 119. 148. 342.   0. 153.  97.
#   219. 267. 196. 275. 227. 137. 225. 235.  74. 249.]
#  [180. 315. 188. 193. 245. 258. 228.  29. 159. 342. 209. 153.   0. 219.
#   134. 170.  99. 178. 130.  69. 104. 138.  96. 104.]
#  [ 83. 172. 149.  79. 139. 134. 112. 126.  62. 199. 153.  97. 219.   0.
#   170. 255. 125. 154.  68.  82. 164. 114. 264. 178.]
#  [ 50. 232. 264. 148. 232. 203. 190. 248. 122. 259. 227. 219. 134. 170.
#     0. 125. 173. 190. 230. 223.  99. 212. 187.  60.]
#  [219.  92.  82. 119.  31.  43.  58. 238. 147.  84.  53. 267. 170. 255.
#   125.   0. 190.  79.  57.  90.  57.  39. 182.  96.]
#  [ 74.  81. 182. 105. 150. 121. 108. 310.  37. 160. 145. 196.  99. 125.
#   173. 190.   0.  57.  86. 176. 112.  40. 261. 175.]
#  [139.  98. 261. 144. 176. 164. 136. 389. 116. 147. 224. 275. 178. 154.
#   190.  79.  57.   0. 176.  90. 114.  46. 239. 153.]
#  [ 53. 138. 239. 123. 207. 178. 165. 367.  86. 187. 202. 227. 130.  68.
#   230.  57.  86. 176.   0. 114. 134. 136. 165. 146.]
#  [ 43. 200. 232.  98. 200. 171. 131. 166.  90. 227. 195. 137.  69.  82.
#   223.  90. 176.  90. 114.   0. 136.  96. 151.  47.]
#  [128.  76. 146.  32.  76.  47.  30. 222.  56. 103. 109. 225. 104. 164.
#    99.  57. 112. 114. 134. 136.   0. 151. 221. 135.]
#  [ 99.  89. 221. 105. 189. 160. 147. 349.  76. 138. 184. 235. 138. 114.
#   212.  39.  40.  46. 136.  96. 151.   0. 135. 169.]
#  [228. 235. 108. 119. 165. 178. 154.  71. 136. 262. 110.  74.  96. 264.
#   187. 182. 261. 239. 165. 151. 221. 135.   0. 192.]
#  [142.  99.  84.  35.  29.  42.  36. 220.  70. 126.  55. 249. 104. 178.
#    60.  96. 175. 153. 146.  47. 135. 169. 192. 121.]]

# %%
import networkx as nx
import numpy as np
import random
import time
from networkx.algorithms.matching import min_weight_matching


def build_graph_from_distance_matrix(distance_matrix):
    G = nx.Graph()
    for i in range(len(distance_matrix)):
        for j in range(i + 1, len(distance_matrix)):
            G.add_edge(i, j, weight=distance_matrix[i][j])
    return G
# Pour générer une solution initiale on pourais utiliser l'heuristique de Cristofid déjà implémenté
def christofides_algorithm(G):
    # Trouver un arbre couvrant minimal
    T = nx.minimum_spanning_tree(G, weight='weight')

    # Trouver les sommets de degré impair dans l'arbre couvrant minimal
    odd_degree_nodes = [node for node in T.nodes() if T.degree(node) % 2 == 1]

    # Restreindre le graphe aux sommets de degré impair
    odd_graph = G.subgraph(odd_degree_nodes)

    # Trouver un matching parfait de poids minimum dans le graphe restreint
    matching = min_weight_matching(odd_graph)

    # Ajouter le matching à l'arbre couvrant minimal pour obtenir un multigraphe
    multigraph = nx.MultiGraph(T)
    for edge in matching:
        multigraph.add_edge(edge[0], edge[1], weight=G[edge[0]][edge[1]]['weight'])

    # Trouver un circuit Eulerien dans le multigraphe
    eulerian_circuit = list(nx.eulerian_circuit(multigraph))

    # Convertir le circuit Eulerien en un circuit Hamiltonien et calculer le coût
    visited = set()
    hamiltonian_circuit = []
    total_cost = 0
    last_node = None
    #print(eulerian_circuit)
    for u, v in eulerian_circuit:
        if u not in visited:
            if last_node is not None:
                total_cost += G[last_node][u]['weight']
            visited.add(u)
            hamiltonian_circuit.append(u)
            last_node = u
        if v not in visited:
            if last_node is not None:
                total_cost += G[last_node][v]['weight']
            visited.add(v)
            hamiltonian_circuit.append(v)
            last_node = v
    # Ajouter le coût pour retourner au point de départ
    # Ajouter le coût pour retourner au point de départ pour former un cycle
    if hamiltonian_circuit:
        start_node = hamiltonian_circuit[0]
        end_node = hamiltonian_circuit[-1]
        if start_node != end_node:
            hamiltonian_circuit.append(start_node)
            total_cost += G[end_node][start_node]['weight']

    return hamiltonian_circuit, total_cost



# Fonction pour calculer le coût d'une solution
def calculer_cout(S, matrice_distances):
    cout = 0
    n = len(S)
    for i in range(n):
        cout += matrice_distances[S[i]][S[(i + 1) % n]]  # Distance entre la ville i et i+1
    return cout

# Fonction pour générer une solution initiale
def generer_solution_initiale(distance_matrix):
    G=build_graph_from_distance_matrix(distance_matrix)
    hamiltonian_circuit, total_cost = christofides_algorithm(G)
    return hamiltonian_circuit
# Fonction pour générer un voisinage (2-opt swap)
def generer_voisinage(solution):
    voisinage = []
    for i in range(1, len(solution) - 1):
        for j in range(i + 1, len(solution)):
            voisin = solution[:]
            voisin[i:j] = voisin[i:j][::-1]
            voisinage.append(voisin)
    return voisinage

# Implémentation de l'algorithme de recherche tabou
def recherche_tabou(matrice_distances, nb_iterations_max, taille_liste_tabou):

    # Initialisations
    solution_courante = generer_solution_initiale(matrice_distances)
    meilleure_solution = solution_courante[:]
    cout_meilleure_solution = calculer_cout(meilleure_solution, matrice_distances)
    liste_tabou = []

    # Boucle principale
    for iteration in range(nb_iterations_max):
        voisinage = generer_voisinage(solution_courante)
        couts_voisinage = [calculer_cout(voisin, matrice_distances) for voisin in voisinage]
        # Sélection du meilleur voisin non tabou ou qui respecte le critère d'aspiration
        voisinage_et_couts = sorted([(voisin, cout) for voisin, cout in zip(voisinage, couts_voisinage)], key=lambda x: x[1])
        for voisin, cout_voisin in voisinage_et_couts:
            if (tuple(voisin), cout_voisin) not in liste_tabou or cout_voisin < cout_meilleure_solution:
                solution_courante = voisin
                cout_solution_courante = cout_voisin
                break

        # Mise à jour de la liste tabou
        if len(liste_tabou) >= taille_liste_tabou:
            liste_tabou.pop(0)  # Supprime le plus ancien si la taille maximale est atteinte
        liste_tabou.append((tuple(solution_courante), cout_solution_courante))

        # Mise à jour de la meilleure solution
        if cout_solution_courante < cout_meilleure_solution:
            meilleure_solution = solution_courante[:]
            cout_meilleure_solution = cout_solution_courante

        print(f"Iteration {iteration}: Cout actuel = {cout_solution_courante}, Meilleur cout = {cout_meilleure_solution}")

    return meilleure_solution, cout_meilleure_solution

# Exemple d'utilisation de l'algorithme de recherche tabou pour le TSP
nb_villes = 16
# Création d'une matrice de distances aléatoire et symétrique avec des diagonales nulles
'''matrice_distances = [
[0, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80],
[10, 0, 25, 35, 15, 20, 30, 5, 40, 35, 45, 50, 55, 60, 65, 70],
[15, 25, 0, 5, 10, 30, 40, 15, 25, 30, 20, 45, 30, 35, 40, 50],
[20, 35, 5, 0, 40, 25, 15, 10, 20, 45, 30, 35, 40, 50, 55, 60],
[25, 15, 10, 40, 0, 20, 10, 25, 30, 35, 50, 55, 60, 65, 70, 75],
[30, 20, 30, 25, 20, 0, 35, 30, 5, 15, 40, 45, 50, 55, 60, 65],
[35, 30, 40, 15, 10, 35, 0, 20, 25, 30, 45, 60, 65, 70, 75, 80],
[40, 5, 15, 10, 25, 30, 20, 0, 35, 40, 55, 35, 40, 45, 50, 55],
[45, 40, 25, 20, 30, 5, 25, 35, 0, 15, 10, 25, 30, 35, 40, 45],
[50, 35, 30, 45, 35, 15, 30, 40, 15, 0, 25, 20, 15, 20, 25, 30],
[55, 45, 20, 30, 50, 40, 45, 55, 10, 25, 0, 15, 30, 35, 40, 45],
[60, 50, 45, 35, 55, 45, 60, 35, 25, 20, 15, 0, 10, 15, 20, 25],
[65, 55, 30, 40, 60, 50, 65, 40, 30, 15, 30, 10, 0, 25, 30, 35],
[70, 60, 35, 50, 65, 55, 70, 45, 35, 20, 35, 15, 25, 0, 10, 15],
[75, 65, 40, 55, 70, 60, 75, 50, 40, 25, 40, 20, 30, 10, 0, 5],
[80, 70, 50, 60, 75, 65, 80, 55, 45, 30, 45, 25, 35, 15, 5, 0]
]'''

# Paramètres de l'algorithme
nb_iterations_max = 1000
taille_liste_tabou = 10

# Lancement de l'algorithme
meilleure_solution, cout_meilleure_solution = recherche_tabou(matrice_distances, nb_iterations_max, taille_liste_tabou)
# Out:
# Iteration 0: Cout actuel = 1998.0, Meilleur cout = 1998.0
# Iteration 1: Cout actuel = 1768.0, Meilleur cout = 1768.0
# Iteration 2: Cout actuel = 1624.0, Meilleur cout = 1624.0
# Iteration 3: Cout actuel = 1631.0, Meilleur cout = 1624.0
# Iteration 4: Cout actuel = 1662.0, Meilleur cout = 1624.0
# Iteration 5: Cout actuel = 1655.0, Meilleur cout = 1624.0
# Iteration 6: Cout actuel = 1714.0, Meilleur cout = 1624.0
# Iteration 7: Cout actuel = 1603.0, Meilleur cout = 1603.0
# Iteration 8: Cout actuel = 1610.0, Meilleur cout = 1603.0
# Iteration 9: Cout actuel = 1657.0, Meilleur cout = 1603.0
# Iteration 10: Cout actuel = 1525.0, Meilleur cout = 1525.0
# Iteration 11: Cout actuel = 1631.0, Meilleur cout = 1525.0
# Iteration 12: Cout actuel = 1639.0, Meilleur cout = 1525.0
# Iteration 13: Cout actuel = 1546.0, Meilleur cout = 1525.0
# Iteration 14: Cout actuel = 1577.0, Meilleur cout = 1525.0
# Iteration 15: Cout actuel = 1636.0, Meilleur cout = 1525.0
# Iteration 16: Cout actuel = 1707.0, Meilleur cout = 1525.0
# Iteration 17: Cout actuel = 1685.0, Meilleur cout = 1525.0
# Iteration 18: Cout actuel = 1793.0, Meilleur cout = 1525.0
# Iteration 19: Cout actuel = 1718.0, Meilleur cout = 1525.0
# Iteration 20: Cout actuel = 1674.0, Meilleur cout = 1525.0
# Iteration 21: Cout actuel = 1771.0, Meilleur cout = 1525.0
# Iteration 22: Cout actuel = 1897.0, Meilleur cout = 1525.0
# Iteration 23: Cout actuel = 1703.0, Meilleur cout = 1525.0
# Iteration 24: Cout actuel = 1564.0, Meilleur cout = 1525.0
# Iteration 25: Cout actuel = 1533.0, Meilleur cout = 1525.0
# Iteration 26: Cout actuel = 1573.0, Meilleur cout = 1525.0
# Iteration 27: Cout actuel = 1563.0, Meilleur cout = 1525.0
# Iteration 28: Cout actuel = 1400.0, Meilleur cout = 1400.0
# Iteration 29: Cout actuel = 1431.0, Meilleur cout = 1400.0
# Iteration 30: Cout actuel = 1490.0, Meilleur cout = 1400.0
# Iteration 31: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 32: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 33: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 34: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 35: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 36: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 37: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 38: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 39: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 40: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 41: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 42: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 43: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 44: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 45: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 46: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 47: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 48: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 49: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 50: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 51: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 52: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 53: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 54: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 55: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 56: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 57: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 58: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 59: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 60: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 61: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 62: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 63: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 64: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 65: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 66: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 67: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 68: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 69: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 70: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 71: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 72: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 73: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 74: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 75: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 76: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 77: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 78: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 79: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 80: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 81: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 82: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 83: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 84: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 85: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 86: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 87: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 88: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 89: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 90: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 91: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 92: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 93: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 94: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 95: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 96: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 97: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 98: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 99: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 100: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 101: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 102: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 103: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 104: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 105: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 106: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 107: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 108: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 109: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 110: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 111: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 112: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 113: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 114: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 115: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 116: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 117: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 118: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 119: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 120: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 121: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 122: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 123: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 124: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 125: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 126: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 127: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 128: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 129: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 130: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 131: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 132: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 133: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 134: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 135: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 136: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 137: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 138: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 139: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 140: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 141: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 142: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 143: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 144: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 145: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 146: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 147: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 148: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 149: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 150: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 151: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 152: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 153: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 154: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 155: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 156: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 157: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 158: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 159: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 160: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 161: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 162: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 163: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 164: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 165: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 166: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 167: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 168: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 169: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 170: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 171: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 172: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 173: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 174: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 175: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 176: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 177: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 178: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 179: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 180: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 181: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 182: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 183: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 184: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 185: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 186: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 187: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 188: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 189: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 190: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 191: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 192: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 193: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 194: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 195: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 196: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 197: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 198: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 199: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 200: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 201: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 202: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 203: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 204: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 205: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 206: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 207: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 208: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 209: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 210: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 211: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 212: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 213: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 214: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 215: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 216: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 217: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 218: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 219: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 220: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 221: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 222: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 223: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 224: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 225: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 226: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 227: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 228: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 229: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 230: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 231: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 232: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 233: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 234: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 235: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 236: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 237: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 238: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 239: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 240: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 241: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 242: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 243: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 244: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 245: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 246: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 247: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 248: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 249: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 250: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 251: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 252: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 253: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 254: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 255: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 256: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 257: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 258: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 259: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 260: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 261: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 262: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 263: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 264: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 265: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 266: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 267: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 268: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 269: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 270: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 271: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 272: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 273: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 274: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 275: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 276: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 277: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 278: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 279: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 280: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 281: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 282: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 283: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 284: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 285: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 286: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 287: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 288: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 289: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 290: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 291: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 292: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 293: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 294: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 295: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 296: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 297: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 298: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 299: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 300: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 301: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 302: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 303: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 304: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 305: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 306: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 307: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 308: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 309: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 310: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 311: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 312: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 313: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 314: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 315: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 316: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 317: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 318: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 319: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 320: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 321: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 322: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 323: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 324: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 325: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 326: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 327: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 328: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 329: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 330: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 331: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 332: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 333: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 334: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 335: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 336: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 337: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 338: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 339: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 340: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 341: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 342: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 343: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 344: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 345: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 346: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 347: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 348: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 349: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 350: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 351: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 352: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 353: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 354: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 355: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 356: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 357: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 358: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 359: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 360: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 361: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 362: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 363: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 364: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 365: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 366: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 367: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 368: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 369: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 370: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 371: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 372: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 373: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 374: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 375: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 376: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 377: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 378: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 379: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 380: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 381: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 382: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 383: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 384: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 385: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 386: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 387: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 388: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 389: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 390: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 391: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 392: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 393: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 394: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 395: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 396: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 397: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 398: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 399: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 400: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 401: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 402: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 403: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 404: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 405: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 406: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 407: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 408: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 409: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 410: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 411: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 412: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 413: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 414: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 415: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 416: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 417: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 418: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 419: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 420: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 421: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 422: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 423: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 424: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 425: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 426: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 427: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 428: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 429: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 430: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 431: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 432: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 433: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 434: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 435: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 436: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 437: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 438: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 439: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 440: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 441: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 442: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 443: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 444: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 445: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 446: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 447: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 448: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 449: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 450: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 451: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 452: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 453: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 454: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 455: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 456: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 457: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 458: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 459: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 460: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 461: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 462: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 463: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 464: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 465: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 466: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 467: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 468: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 469: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 470: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 471: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 472: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 473: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 474: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 475: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 476: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 477: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 478: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 479: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 480: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 481: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 482: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 483: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 484: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 485: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 486: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 487: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 488: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 489: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 490: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 491: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 492: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 493: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 494: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 495: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 496: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 497: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 498: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 499: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 500: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 501: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 502: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 503: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 504: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 505: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 506: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 507: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 508: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 509: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 510: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 511: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 512: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 513: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 514: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 515: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 516: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 517: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 518: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 519: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 520: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 521: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 522: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 523: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 524: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 525: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 526: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 527: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 528: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 529: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 530: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 531: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 532: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 533: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 534: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 535: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 536: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 537: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 538: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 539: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 540: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 541: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 542: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 543: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 544: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 545: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 546: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 547: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 548: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 549: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 550: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 551: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 552: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 553: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 554: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 555: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 556: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 557: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 558: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 559: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 560: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 561: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 562: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 563: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 564: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 565: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 566: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 567: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 568: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 569: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 570: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 571: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 572: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 573: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 574: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 575: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 576: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 577: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 578: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 579: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 580: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 581: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 582: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 583: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 584: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 585: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 586: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 587: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 588: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 589: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 590: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 591: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 592: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 593: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 594: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 595: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 596: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 597: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 598: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 599: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 600: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 601: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 602: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 603: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 604: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 605: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 606: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 607: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 608: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 609: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 610: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 611: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 612: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 613: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 614: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 615: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 616: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 617: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 618: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 619: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 620: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 621: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 622: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 623: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 624: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 625: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 626: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 627: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 628: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 629: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 630: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 631: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 632: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 633: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 634: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 635: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 636: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 637: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 638: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 639: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 640: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 641: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 642: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 643: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 644: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 645: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 646: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 647: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 648: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 649: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 650: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 651: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 652: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 653: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 654: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 655: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 656: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 657: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 658: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 659: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 660: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 661: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 662: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 663: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 664: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 665: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 666: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 667: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 668: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 669: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 670: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 671: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 672: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 673: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 674: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 675: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 676: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 677: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 678: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 679: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 680: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 681: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 682: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 683: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 684: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 685: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 686: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 687: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 688: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 689: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 690: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 691: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 692: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 693: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 694: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 695: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 696: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 697: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 698: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 699: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 700: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 701: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 702: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 703: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 704: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 705: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 706: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 707: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 708: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 709: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 710: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 711: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 712: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 713: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 714: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 715: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 716: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 717: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 718: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 719: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 720: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 721: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 722: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 723: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 724: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 725: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 726: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 727: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 728: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 729: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 730: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 731: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 732: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 733: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 734: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 735: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 736: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 737: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 738: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 739: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 740: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 741: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 742: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 743: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 744: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 745: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 746: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 747: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 748: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 749: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 750: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 751: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 752: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 753: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 754: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 755: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 756: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 757: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 758: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 759: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 760: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 761: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 762: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 763: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 764: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 765: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 766: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 767: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 768: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 769: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 770: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 771: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 772: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 773: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 774: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 775: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 776: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 777: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 778: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 779: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 780: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 781: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 782: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 783: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 784: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 785: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 786: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 787: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 788: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 789: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 790: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 791: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 792: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 793: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 794: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 795: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 796: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 797: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 798: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 799: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 800: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 801: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 802: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 803: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 804: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 805: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 806: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 807: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 808: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 809: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 810: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 811: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 812: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 813: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 814: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 815: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 816: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 817: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 818: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 819: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 820: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 821: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 822: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 823: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 824: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 825: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 826: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 827: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 828: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 829: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 830: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 831: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 832: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 833: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 834: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 835: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 836: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 837: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 838: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 839: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 840: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 841: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 842: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 843: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 844: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 845: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 846: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 847: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 848: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 849: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 850: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 851: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 852: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 853: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 854: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 855: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 856: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 857: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 858: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 859: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 860: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 861: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 862: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 863: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 864: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 865: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 866: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 867: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 868: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 869: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 870: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 871: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 872: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 873: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 874: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 875: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 876: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 877: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 878: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 879: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 880: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 881: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 882: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 883: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 884: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 885: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 886: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 887: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 888: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 889: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 890: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 891: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 892: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 893: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 894: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 895: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 896: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 897: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 898: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 899: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 900: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 901: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 902: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 903: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 904: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 905: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 906: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 907: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 908: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 909: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 910: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 911: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 912: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 913: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 914: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 915: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 916: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 917: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 918: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 919: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 920: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 921: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 922: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 923: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 924: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 925: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 926: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 927: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 928: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 929: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 930: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 931: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 932: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 933: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 934: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 935: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 936: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 937: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 938: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 939: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 940: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 941: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 942: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 943: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 944: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 945: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 946: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 947: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 948: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 949: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 950: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 951: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 952: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 953: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 954: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 955: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 956: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 957: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 958: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 959: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 960: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 961: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 962: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 963: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 964: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 965: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 966: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 967: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 968: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 969: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 970: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 971: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 972: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 973: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 974: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 975: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 976: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 977: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 978: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 979: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 980: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 981: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 982: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 983: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 984: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 985: Cout actuel = 1490.0, Meilleur cout = 1379.0
# Iteration 986: Cout actuel = 1561.0, Meilleur cout = 1379.0
# Iteration 987: Cout actuel = 1539.0, Meilleur cout = 1379.0
# Iteration 988: Cout actuel = 1647.0, Meilleur cout = 1379.0
# Iteration 989: Cout actuel = 1572.0, Meilleur cout = 1379.0
# Iteration 990: Cout actuel = 1528.0, Meilleur cout = 1379.0
# Iteration 991: Cout actuel = 1625.0, Meilleur cout = 1379.0
# Iteration 992: Cout actuel = 1753.0, Meilleur cout = 1379.0
# Iteration 993: Cout actuel = 1660.0, Meilleur cout = 1379.0
# Iteration 994: Cout actuel = 1379.0, Meilleur cout = 1379.0
# Iteration 995: Cout actuel = 1485.0, Meilleur cout = 1379.0
# Iteration 996: Cout actuel = 1493.0, Meilleur cout = 1379.0
# Iteration 997: Cout actuel = 1400.0, Meilleur cout = 1379.0
# Iteration 998: Cout actuel = 1431.0, Meilleur cout = 1379.0
# Iteration 999: Cout actuel = 1490.0, Meilleur cout = 1379.0

# %% [markdown]
# # Avec diversification et Intensification

# %%
import math
import time
def calculate_distance(coord1, coord2):
    return math.sqrt((coord1[0] - coord2[0])**2 + (coord1[1] - coord2[1])**2)

def read_tsp_file(file_path):
    coordinates = {}
    with open(file_path, 'r') as file:
        lines = file.readlines()
        node_coord_section_index = lines.index('NODE_COORD_SECTION\n')
        for line in lines[node_coord_section_index + 1:]:
            if line.strip() == 'EOF':
                break
            parts = line.strip().split()
            node_id = int(parts[0])
            x, y = map(float, parts[1:])
            coordinates[node_id] = (x, y)
    return coordinates


def create_distance_matrix(coordinates):
    num_cities = len(coordinates)
    distance_matrix = [[0] * num_cities for _ in range(num_cities)]

    for i in range(1, num_cities + 1):
        for j in range(1, num_cities + 1):
            distance_matrix[i - 1][j - 1] = calculate_distance(coordinates[i], coordinates[j])

    return distance_matrix

# Example usage
file_path = "/content/gil262.tsp"
coordinates = read_tsp_file(file_path)
matrice_distances = create_distance_matrix(coordinates)

# %%
import xml.etree.ElementTree as ET
import numpy as np

def load_xml_and_extract_matrix(xml_file_path):
    # Charger le fichier XML
    tree = ET.parse(xml_file_path)
    root = tree.getroot()

    # Trouver l'élément 'graph' qui contient les données de la matrice
    graph_element = root.find('graph')

    # Extraire la matrice symétrique
    return extract_symmetric_matrix(graph_element)

def extract_symmetric_matrix(graph_element):
    num_vertices = len(graph_element)  # Nombre de vertices (supposé carré)
    matrix = np.zeros((num_vertices, num_vertices), dtype=float)  # Initialiser la matrice de zéros

    # Parcourir chaque vertex
    for i, vertex in enumerate(graph_element):
        # Parcourir chaque edge du vertex
        for edge in vertex:
            j = int(edge.text) - 1  # Index du vertex connecté (base 1 à base 0)
            if i != j:  # Éviter de remplir la diagonale
                cost = float(edge.attrib['cost'])  # Coût de l'edge
                matrix[i, j] = cost
                matrix[j, i] = cost  # Assurer la symétrie

    return matrix

# Utiliser la fonction
file_path = '/content/gr17.xml'  # Remplacer par le chemin réel du fichier
matrice_distances = load_xml_and_extract_matrix(file_path)
print(matrice_distances)
# Out:
# [[  0. 257. 390. 661. 227. 488. 572. 530. 555. 289. 282. 638. 567. 466.
#   420. 745. 518.]
#  [257.   0. 661. 228. 169. 112. 196. 154. 372. 262. 110. 437. 191.  74.
#    53. 472. 142.]
#  [390. 661.   0. 169. 383. 120.  77. 105. 175. 476. 324. 240.  27. 182.
#   239. 237.  84.]
#  [661. 228. 169.   0. 120. 267. 351. 309. 338. 196.  61. 421. 346. 243.
#   199. 528. 297.]
#  [227. 169. 383. 120.   0. 351.  63.  34. 264. 360. 208. 329.  83. 105.
#   123. 364.  35.]
#  [488. 112. 120. 267. 351.   0.  34.  29. 232. 444. 292. 297.  47. 150.
#   207. 332.  29.]
#  [572. 196.  77. 351.  63.  34.   0. 232. 249. 402. 250. 314.  68. 108.
#   165. 349.  36.]
#  [530. 154. 105. 309.  34.  29. 232.   0. 402. 495. 352.  95. 189. 326.
#   383. 202. 236.]
#  [555. 372. 175. 338. 264. 232. 249. 402.   0. 352. 154. 578. 439. 336.
#   240. 685. 390.]
#  [289. 262. 476. 196. 360. 444. 402. 495. 352.   0. 578. 435. 287. 184.
#   140. 542. 238.]
#  [282. 110. 324.  61. 208. 292. 250. 352. 154. 578.   0. 287. 254. 391.
#   448. 157. 301.]
#  [638. 437. 240. 421. 329. 297. 314.  95. 578. 435. 287.   0. 391. 145.
#   202. 289.  55.]
#  [567. 191.  27. 346.  83.  47.  68. 189. 439. 287. 254. 391.   0. 202.
#    57. 426.  96.]
#  [466.  74. 182. 243. 105. 150. 108. 326. 336. 184. 391. 145. 202.   0.
#   426. 483. 153.]
#  [420.  53. 239. 199. 123. 207. 165. 383. 240. 140. 448. 202.  57. 426.
#     0. 153. 336.]
#  [745. 472. 237. 528. 364. 332. 349. 202. 685. 542. 157. 289. 426. 483.
#   153.   0. 246.]
#  [518. 142.  84. 297.  35.  29.  36. 236. 390. 238. 301.  55.  96. 153.
#   336. 246. 121.]]

# %%
import numpy as np
import random
import time
# Fonction pour calculer le coût d'une solution
def calculer_cout(S, matrice_distances):
    cout = 0
    n = len(S)
    for i in range(n):
        cout += matrice_distances[S[i]][S[(i + 1) % n]]  # Distance entre la ville i et i+1
    return cout

# Fonction pour générer une solution initiale
def generer_solution_initiale(nb_villes):
    solution = list(range(nb_villes))
    random.shuffle(solution)
    return solution

# Fonction pour générer un voisinage (2-opt swap)
def generer_voisinage(solution):
    voisinage = []
    for i in range(1, len(solution) - 1):
        for j in range(i + 1, len(solution)):
            voisin = solution[:]
            voisin[i:j] = voisin[i:j][::-1]
            voisinage.append(voisin)
    return voisinage

# Implémentation de l'algorithme de recherche tabou
def recherche_tabou(matrice_distances, nb_iterations_max, taille_liste_tabou):
    nb_villes = len(matrice_distances)

    # Initialisations
    solution_courante = generer_solution_initiale(nb_villes)
    meilleure_solution = solution_courante[:]
    cout_meilleure_solution = calculer_cout(meilleure_solution, matrice_distances)
    liste_tabou = []

    # Boucle principale
    for iteration in range(nb_iterations_max):
        voisinage = generer_voisinage(solution_courante)
        couts_voisinage = [calculer_cout(voisin, matrice_distances) for voisin in voisinage]
        # Sélection du meilleur voisin non tabou ou qui respecte le critère d'aspiration
        voisinage_et_couts = sorted([(voisin, cout) for voisin, cout in zip(voisinage, couts_voisinage)], key=lambda x: x[1])
        for voisin, cout_voisin in voisinage_et_couts:
            if (tuple(voisin), cout_voisin) not in liste_tabou or cout_voisin < cout_meilleure_solution:
                solution_courante = voisin
                cout_solution_courante = cout_voisin
                break

        # Mise à jour de la liste tabou
        if len(liste_tabou) >= taille_liste_tabou:
            liste_tabou.pop(0)  # Supprime le plus ancien si la taille maximale est atteinte
        liste_tabou.append((tuple(solution_courante), cout_solution_courante))

        # Mise à jour de la meilleure solution
        if cout_solution_courante < cout_meilleure_solution:
            meilleure_solution = solution_courante[:]
            cout_meilleure_solution = cout_solution_courante

        print(f"Iteration {iteration}: Cout actuel = {cout_solution_courante}, Meilleur cout = {cout_meilleure_solution}")

    return meilleure_solution, cout_meilleure_solution

# Exemple d'utilisation de l'algorithme de recherche tabou pour le TSP
nb_villes = 101
# Création d'une matrice de distances aléatoire et symétrique avec des diagonales nulles
'''matrice_distances = [
[0, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80],
[10, 0, 25, 35, 15, 20, 30, 5, 40, 35, 45, 50, 55, 60, 65, 70],
[15, 25, 0, 5, 10, 30, 40, 15, 25, 30, 20, 45, 30, 35, 40, 50],
[20, 35, 5, 0, 40, 25, 15, 10, 20, 45, 30, 35, 40, 50, 55, 60],
[25, 15, 10, 40, 0, 20, 10, 25, 30, 35, 50, 55, 60, 65, 70, 75],
[30, 20, 30, 25, 20, 0, 35, 30, 5, 15, 40, 45, 50, 55, 60, 65],
[35, 30, 40, 15, 10, 35, 0, 20, 25, 30, 45, 60, 65, 70, 75, 80],
[40, 5, 15, 10, 25, 30, 20, 0, 35, 40, 55, 35, 40, 45, 50, 55],
[45, 40, 25, 20, 30, 5, 25, 35, 0, 15, 10, 25, 30, 35, 40, 45],
[50, 35, 30, 45, 35, 15, 30, 40, 15, 0, 25, 20, 15, 20, 25, 30],
[55, 45, 20, 30, 50, 40, 45, 55, 10, 25, 0, 15, 30, 35, 40, 45],
[60, 50, 45, 35, 55, 45, 60, 35, 25, 20, 15, 0, 10, 15, 20, 25],
[65, 55, 30, 40, 60, 50, 65, 40, 30, 15, 30, 10, 0, 25, 30, 35],
[70, 60, 35, 50, 65, 55, 70, 45, 35, 20, 35, 15, 25, 0, 10, 15],
[75, 65, 40, 55, 70, 60, 75, 50, 40, 25, 40, 20, 30, 10, 0, 5],
[80, 70, 50, 60, 75, 65, 80, 55, 45, 30, 45, 25, 35, 15, 5, 0]
]'''

# Paramètres de l'algorithme
nb_iterations_max = 500
taille_liste_tabou = 15
start_time = time.time()
# Lancement de l'algorithme
meilleure_solution, cout_meilleure_solution = recherche_tabou(matrice_distances, nb_iterations_max, taille_liste_tabou)


end_time = time.time()
elapsed_time = end_time - start_time

print(f"Elapsed Time: {elapsed_time} seconds")
# Out:
# Iteration 0: Cout actuel = 26383.431599026764, Meilleur cout = 26383.431599026764
# Iteration 1: Cout actuel = 26026.05613605027, Meilleur cout = 26026.05613605027
# Iteration 2: Cout actuel = 25672.49563446058, Meilleur cout = 25672.49563446058
# Iteration 3: Cout actuel = 25323.545611044654, Meilleur cout = 25323.545611044654
# Iteration 4: Cout actuel = 24986.164721197536, Meilleur cout = 24986.164721197536
# Iteration 5: Cout actuel = 24660.32356914181, Meilleur cout = 24660.32356914181
# Iteration 6: Cout actuel = 24355.945780168957, Meilleur cout = 24355.945780168957
# Iteration 7: Cout actuel = 24051.539555969706, Meilleur cout = 24051.539555969706
# Iteration 8: Cout actuel = 23748.9442178186, Meilleur cout = 23748.9442178186
# Iteration 9: Cout actuel = 23447.327756451, Meilleur cout = 23447.327756451
# Iteration 10: Cout actuel = 23146.878970116035, Meilleur cout = 23146.878970116035
# Iteration 11: Cout actuel = 22852.84234051185, Meilleur cout = 22852.84234051185
# Iteration 12: Cout actuel = 22561.420960243024, Meilleur cout = 22561.420960243024
# Iteration 13: Cout actuel = 22270.82659002843, Meilleur cout = 22270.82659002843
# Iteration 14: Cout actuel = 21980.773574426676, Meilleur cout = 21980.773574426676
# Iteration 15: Cout actuel = 21696.20248233278, Meilleur cout = 21696.20248233278
# Iteration 16: Cout actuel = 21413.82144185825, Meilleur cout = 21413.82144185825
# Iteration 17: Cout actuel = 21152.98766638307, Meilleur cout = 21152.98766638307
# Iteration 18: Cout actuel = 20878.567287959097, Meilleur cout = 20878.567287959097
# Iteration 19: Cout actuel = 20620.534981760702, Meilleur cout = 20620.534981760702
# Iteration 20: Cout actuel = 20363.614648798233, Meilleur cout = 20363.614648798233
# Iteration 21: Cout actuel = 20108.202049661155, Meilleur cout = 20108.202049661155
# Iteration 22: Cout actuel = 19864.171608844503, Meilleur cout = 19864.171608844503
# Iteration 23: Cout actuel = 19615.6035369527, Meilleur cout = 19615.6035369527
# Iteration 24: Cout actuel = 19342.293446703312, Meilleur cout = 19342.293446703312
# Iteration 25: Cout actuel = 19093.810412502797, Meilleur cout = 19093.810412502797
# Iteration 26: Cout actuel = 18859.698160292122, Meilleur cout = 18859.698160292122
# Iteration 27: Cout actuel = 18617.824036986232, Meilleur cout = 18617.824036986232
# Iteration 28: Cout actuel = 18374.254851699618, Meilleur cout = 18374.254851699618
# Iteration 29: Cout actuel = 18142.57326539959, Meilleur cout = 18142.57326539959
# Iteration 30: Cout actuel = 17911.505888068332, Meilleur cout = 17911.505888068332
# Iteration 31: Cout actuel = 17679.702718881745, Meilleur cout = 17679.702718881745
# Iteration 32: Cout actuel = 17441.407654940915, Meilleur cout = 17441.407654940915
# Iteration 33: Cout actuel = 17213.060538167323, Meilleur cout = 17213.060538167323
# Iteration 34: Cout actuel = 16989.079223009237, Meilleur cout = 16989.079223009237
# Iteration 35: Cout actuel = 16766.661417929645, Meilleur cout = 16766.661417929645
# Iteration 36: Cout actuel = 16545.109417447246, Meilleur cout = 16545.109417447246
# Iteration 37: Cout actuel = 16327.787311945245, Meilleur cout = 16327.787311945245
# Iteration 38: Cout actuel = 16109.40260523423, Meilleur cout = 16109.40260523423
# Iteration 39: Cout actuel = 15878.737794121458, Meilleur cout = 15878.737794121458
# Iteration 40: Cout actuel = 15665.112677043042, Meilleur cout = 15665.112677043042
# Iteration 41: Cout actuel = 15457.284326736772, Meilleur cout = 15457.284326736772
# Iteration 42: Cout actuel = 15246.420820890886, Meilleur cout = 15246.420820890886
# Iteration 43: Cout actuel = 15038.546400692387, Meilleur cout = 15038.546400692387
# Iteration 44: Cout actuel = 14835.00128496678, Meilleur cout = 14835.00128496678
# Iteration 45: Cout actuel = 14638.418229078572, Meilleur cout = 14638.418229078572
# Iteration 46: Cout actuel = 14437.799614612708, Meilleur cout = 14437.799614612708
# Iteration 47: Cout actuel = 14238.8476696871, Meilleur cout = 14238.8476696871
# Iteration 48: Cout actuel = 14045.66581185181, Meilleur cout = 14045.66581185181
# Iteration 49: Cout actuel = 13859.01452948443, Meilleur cout = 13859.01452948443
# Iteration 50: Cout actuel = 13674.392980072873, Meilleur cout = 13674.392980072873
# Iteration 51: Cout actuel = 13489.806468938328, Meilleur cout = 13489.806468938328
# Iteration 52: Cout actuel = 13307.141009726558, Meilleur cout = 13307.141009726558
# Iteration 53: Cout actuel = 13126.223696093908, Meilleur cout = 13126.223696093908
# Iteration 54: Cout actuel = 12945.861300707908, Meilleur cout = 12945.861300707908
# Iteration 55: Cout actuel = 12767.341466212594, Meilleur cout = 12767.341466212594
# Iteration 56: Cout actuel = 12589.557967149489, Meilleur cout = 12589.557967149489
# Iteration 57: Cout actuel = 12413.188897003769, Meilleur cout = 12413.188897003769
# Iteration 58: Cout actuel = 12236.815925473627, Meilleur cout = 12236.815925473627
# Iteration 59: Cout actuel = 12062.481220671521, Meilleur cout = 12062.481220671521
# Iteration 60: Cout actuel = 11898.412384715357, Meilleur cout = 11898.412384715357
# Iteration 61: Cout actuel = 11734.444416974504, Meilleur cout = 11734.444416974504
# Iteration 62: Cout actuel = 11569.547029930309, Meilleur cout = 11569.547029930309
# Iteration 63: Cout actuel = 11410.501726253573, Meilleur cout = 11410.501726253573
# Iteration 64: Cout actuel = 11260.305690069834, Meilleur cout = 11260.305690069834
# Iteration 65: Cout actuel = 11100.513262458297, Meilleur cout = 11100.513262458297
# Iteration 66: Cout actuel = 10944.648952775959, Meilleur cout = 10944.648952775959
# Iteration 67: Cout actuel = 10789.348279544682, Meilleur cout = 10789.348279544682
# Iteration 68: Cout actuel = 10636.171334047622, Meilleur cout = 10636.171334047622
# Iteration 69: Cout actuel = 10495.407988742882, Meilleur cout = 10495.407988742882
# Iteration 70: Cout actuel = 10360.509576903216, Meilleur cout = 10360.509576903216
# Iteration 71: Cout actuel = 10227.638272359809, Meilleur cout = 10227.638272359809
# Iteration 72: Cout actuel = 10069.602173913081, Meilleur cout = 10069.602173913081
# Iteration 73: Cout actuel = 9923.631930096748, Meilleur cout = 9923.631930096748
# Iteration 74: Cout actuel = 9785.14829059391, Meilleur cout = 9785.14829059391
# Iteration 75: Cout actuel = 9653.149492526423, Meilleur cout = 9653.149492526423
# Iteration 76: Cout actuel = 9522.933536702825, Meilleur cout = 9522.933536702825
# Iteration 77: Cout actuel = 9379.220406175666, Meilleur cout = 9379.220406175666
# Iteration 78: Cout actuel = 9248.228290630806, Meilleur cout = 9248.228290630806
# Iteration 79: Cout actuel = 9118.1494479192, Meilleur cout = 9118.1494479192
# Iteration 80: Cout actuel = 8988.20318313276, Meilleur cout = 8988.20318313276
# Iteration 81: Cout actuel = 8854.3396615766, Meilleur cout = 8854.3396615766
# Iteration 82: Cout actuel = 8724.648891677456, Meilleur cout = 8724.648891677456
# Iteration 83: Cout actuel = 8605.596420320655, Meilleur cout = 8605.596420320655
# Iteration 84: Cout actuel = 8487.489931898932, Meilleur cout = 8487.489931898932
# Iteration 85: Cout actuel = 8359.5499677996, Meilleur cout = 8359.5499677996
# Iteration 86: Cout actuel = 8227.086845113969, Meilleur cout = 8227.086845113969
# Iteration 87: Cout actuel = 8100.341059524715, Meilleur cout = 8100.341059524715
# Iteration 88: Cout actuel = 7989.708675552389, Meilleur cout = 7989.708675552389
# Iteration 89: Cout actuel = 7884.655036948947, Meilleur cout = 7884.655036948947
# Iteration 90: Cout actuel = 7775.557277400336, Meilleur cout = 7775.557277400336
# Iteration 91: Cout actuel = 7674.708823900106, Meilleur cout = 7674.708823900106
# Iteration 92: Cout actuel = 7575.994514684074, Meilleur cout = 7575.994514684074
# Iteration 93: Cout actuel = 7482.2044110465185, Meilleur cout = 7482.2044110465185
# Iteration 94: Cout actuel = 7392.365627043375, Meilleur cout = 7392.365627043375
# Iteration 95: Cout actuel = 7303.80884796033, Meilleur cout = 7303.80884796033
# Iteration 96: Cout actuel = 7215.933629794709, Meilleur cout = 7215.933629794709
# Iteration 97: Cout actuel = 7134.487922663294, Meilleur cout = 7134.487922663294
# Iteration 98: Cout actuel = 7048.870733578108, Meilleur cout = 7048.870733578108
# Iteration 99: Cout actuel = 6965.722915953735, Meilleur cout = 6965.722915953735
# Iteration 100: Cout actuel = 6895.399249716574, Meilleur cout = 6895.399249716574
# Iteration 101: Cout actuel = 6827.379205129593, Meilleur cout = 6827.379205129593
# Iteration 102: Cout actuel = 6760.146482539055, Meilleur cout = 6760.146482539055
# Iteration 103: Cout actuel = 6681.589358559691, Meilleur cout = 6681.589358559691
# Iteration 104: Cout actuel = 6607.586746881996, Meilleur cout = 6607.586746881996
# Iteration 105: Cout actuel = 6528.60644586696, Meilleur cout = 6528.60644586696
# Iteration 106: Cout actuel = 6456.539858478577, Meilleur cout = 6456.539858478577
# Iteration 107: Cout actuel = 6389.272964232719, Meilleur cout = 6389.272964232719
# Iteration 108: Cout actuel = 6325.37872559275, Meilleur cout = 6325.37872559275
# Iteration 109: Cout actuel = 6262.85344631911, Meilleur cout = 6262.85344631911
# Iteration 110: Cout actuel = 6201.613864873602, Meilleur cout = 6201.613864873602
# Iteration 111: Cout actuel = 6141.724546626571, Meilleur cout = 6141.724546626571
# Iteration 112: Cout actuel = 6078.892666639542, Meilleur cout = 6078.892666639542
# Iteration 113: Cout actuel = 6022.077895741554, Meilleur cout = 6022.077895741554
# Iteration 114: Cout actuel = 5962.824719715073, Meilleur cout = 5962.824719715073
# Iteration 115: Cout actuel = 5908.553577653626, Meilleur cout = 5908.553577653626
# Iteration 116: Cout actuel = 5848.096520083473, Meilleur cout = 5848.096520083473
# Iteration 117: Cout actuel = 5795.564614932834, Meilleur cout = 5795.564614932834
# Iteration 118: Cout actuel = 5738.602483125231, Meilleur cout = 5738.602483125231
# Iteration 119: Cout actuel = 5691.144953902341, Meilleur cout = 5691.144953902341
# Iteration 120: Cout actuel = 5641.4272367224585, Meilleur cout = 5641.4272367224585
# Iteration 121: Cout actuel = 5594.816561072694, Meilleur cout = 5594.816561072694
# Iteration 122: Cout actuel = 5548.610396106383, Meilleur cout = 5548.610396106383
# Iteration 123: Cout actuel = 5496.3932591594685, Meilleur cout = 5496.3932591594685
# Iteration 124: Cout actuel = 5446.542700007763, Meilleur cout = 5446.542700007763
# Iteration 125: Cout actuel = 5400.989123976312, Meilleur cout = 5400.989123976312
# Iteration 126: Cout actuel = 5351.870085155114, Meilleur cout = 5351.870085155114
# Iteration 127: Cout actuel = 5307.86436386248, Meilleur cout = 5307.86436386248
# Iteration 128: Cout actuel = 5266.410847769886, Meilleur cout = 5266.410847769886
# Iteration 129: Cout actuel = 5225.511307519689, Meilleur cout = 5225.511307519689
# Iteration 130: Cout actuel = 5180.527324906761, Meilleur cout = 5180.527324906761
# Iteration 131: Cout actuel = 5137.188317911962, Meilleur cout = 5137.188317911962
# Iteration 132: Cout actuel = 5096.166882939521, Meilleur cout = 5096.166882939521
# Iteration 133: Cout actuel = 5055.314305887761, Meilleur cout = 5055.314305887761
# Iteration 134: Cout actuel = 5014.818590969481, Meilleur cout = 5014.818590969481
# Iteration 135: Cout actuel = 4975.910175957165, Meilleur cout = 4975.910175957165
# Iteration 136: Cout actuel = 4937.09073673701, Meilleur cout = 4937.09073673701
# Iteration 137: Cout actuel = 4898.465266343239, Meilleur cout = 4898.465266343239
# Iteration 138: Cout actuel = 4860.511477189756, Meilleur cout = 4860.511477189756
# Iteration 139: Cout actuel = 4819.559861436791, Meilleur cout = 4819.559861436791
# Iteration 140: Cout actuel = 4783.644513229279, Meilleur cout = 4783.644513229279
# Iteration 141: Cout actuel = 4748.412327443716, Meilleur cout = 4748.412327443716
# Iteration 142: Cout actuel = 4713.7352817229175, Meilleur cout = 4713.7352817229175
# Iteration 143: Cout actuel = 4674.710609774555, Meilleur cout = 4674.710609774555
# Iteration 144: Cout actuel = 4640.299028317091, Meilleur cout = 4640.299028317091
# Iteration 145: Cout actuel = 4605.913317399311, Meilleur cout = 4605.913317399311
# Iteration 146: Cout actuel = 4561.330306620201, Meilleur cout = 4561.330306620201
# Iteration 147: Cout actuel = 4528.684974565167, Meilleur cout = 4528.684974565167
# Iteration 148: Cout actuel = 4492.313251162587, Meilleur cout = 4492.313251162587
# Iteration 149: Cout actuel = 4459.799181469629, Meilleur cout = 4459.799181469629
# Iteration 150: Cout actuel = 4428.604640409028, Meilleur cout = 4428.604640409028
# Iteration 151: Cout actuel = 4398.891602192212, Meilleur cout = 4398.891602192212
# Iteration 152: Cout actuel = 4369.687668391003, Meilleur cout = 4369.687668391003
# Iteration 153: Cout actuel = 4340.759149192143, Meilleur cout = 4340.759149192143
# Iteration 154: Cout actuel = 4313.381881686134, Meilleur cout = 4313.381881686134
# Iteration 155: Cout actuel = 4286.1566821767565, Meilleur cout = 4286.1566821767565
# Iteration 156: Cout actuel = 4256.481811825272, Meilleur cout = 4256.481811825272
# Iteration 157: Cout actuel = 4225.504764036513, Meilleur cout = 4225.504764036513
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-42aeeaa2b391> in <cell line: 91>()
#      89 start_time = time.time()
#      90 # Lancement de l'algorithme
# ---> 91 meilleure_solution, cout_meilleure_solution = recherche_tabou(matrice_distances, nb_iterations_max, taille_liste_tabou)
#      92
#      93
#
# <ipython-input-42-42aeeaa2b391> in recherche_tabou(matrice_distances, nb_iterations_max, taille_liste_tabou)
#      39     for iteration in range(nb_iterations_max):
#      40         voisinage = generer_voisinage(solution_courante)
# ---> 41         couts_voisinage = [calculer_cout(voisin, matrice_distances) for voisin in voisinage]
#      42         # Sélection du meilleur voisin non tabou ou qui respecte le critère d'aspiration
#      43         voisinage_et_couts = sorted([(voisin, cout) for voisin, cout in zip(voisinage, couts_voisinage)], key=lambda x: x[1])
#
# <ipython-input-42-42aeeaa2b391> in <listcomp>(.0)
#      39     for iteration in range(nb_iterations_max):
#      40         voisinage = generer_voisinage(solution_courante)
# ---> 41         couts_voisinage = [calculer_cout(voisin, matrice_distances) for voisin in voisinage]
#      42         # Sélection du meilleur voisin non tabou ou qui respecte le critère d'aspiration
#      43         voisinage_et_couts = sorted([(voisin, cout) for voisin, cout in zip(voisinage, couts_voisinage)], key=lambda x: x[1])
#
# <ipython-input-42-42aeeaa2b391> in calculer_cout(S, matrice_distances)
#       7     n = len(S)
#       8     for i in range(n):
# ----> 9         cout += matrice_distances[S[i]][S[(i + 1) % n]]  # Distance entre la ville i et i+1
#      10     return cout
#      11
#
# KeyboardInterrupt:

# %%
import networkx as nx
import numpy as np
import random
import time
from networkx.algorithms.matching import min_weight_matching



def christofides_algorithm(G):
    # Trouver un arbre couvrant minimal
    T = nx.minimum_spanning_tree(G, weight='weight')

    # Trouver les sommets de degré impair dans l'arbre couvrant minimal
    odd_degree_nodes = [node for node in T.nodes() if T.degree(node) % 2 == 1]

    # Restreindre le graphe aux sommets de degré impair
    odd_graph = G.subgraph(odd_degree_nodes)

    # Trouver un matching parfait de poids minimum dans le graphe restreint
    matching = min_weight_matching(odd_graph)

    # Ajouter le matching à l'arbre couvrant minimal pour obtenir un multigraphe
    multigraph = nx.MultiGraph(T)
    for edge in matching:
        multigraph.add_edge(edge[0], edge[1], weight=G[edge[0]][edge[1]]['weight'])

    # Trouver un circuit Eulerien dans le multigraphe
    eulerian_circuit = list(nx.eulerian_circuit(multigraph))

    # Convertir le circuit Eulerien en un circuit Hamiltonien et calculer le coût
    visited = set()
    hamiltonian_circuit = []
    total_cost = 0
    last_node = None
    #print(eulerian_circuit)
    for u, v in eulerian_circuit:
        if u not in visited:
            if last_node is not None:
                total_cost += G[last_node][u]['weight']
            visited.add(u)
            hamiltonian_circuit.append(u)
            last_node = u
        if v not in visited:
            if last_node is not None:
                total_cost += G[last_node][v]['weight']
            visited.add(v)
            hamiltonian_circuit.append(v)
            last_node = v
    # Ajouter le coût pour retourner au point de départ
    # Ajouter le coût pour retourner au point de départ pour former un cycle
    if hamiltonian_circuit:
        start_node = hamiltonian_circuit[0]
        end_node = hamiltonian_circuit[-1]
        if start_node != end_node:
            hamiltonian_circuit.append(start_node)
            total_cost += G[end_node][start_node]['weight']

    return hamiltonian_circuit, total_cost
def build_graph_from_distance_matrix(distance_matrix):
    G = nx.Graph()
    for i in range(len(distance_matrix)):
        for j in range(i + 1, len(distance_matrix)):
            G.add_edge(i, j, weight=distance_matrix[i][j])
    return G
# Vous devriez avoir les fonctions calculer_cout, generer_solution_initiale, generer_voisinage, christofides_algorithm déjà définies comme dans votre code précédent.
def calculate_distance(city1, city2, adjacency_matrix):
    """Calculates the distance between two cities using the adjacency matrix."""
    if isinstance(city1, int) and isinstance(city2, int):
        return adjacency_matrix[city1][city2]
    else:
        raise ValueError("City indices must be integers")


def recherche_locale_2opt(adjacency_matrix, route):
    """Performs the 2-opt algorithm to improve a given route."""
    improved = True
    while improved:
        improved = False
        for i in range(1, len(route) - 2):
            for j in range(i + 2, len(route) - 1):  # Assure that we have at least one element between i and j
                # Calculate the current distances between i and i+1, and j and j+1
                current_distance = calculate_distance(route[i], route[i + 1], adjacency_matrix) + \
                                   calculate_distance(route[j], route[j + 1], adjacency_matrix)

                # Calculate what the distance would be if we swapped i+1 and j
                new_distance = calculate_distance(route[i], route[j], adjacency_matrix) + \
                               calculate_distance(route[i + 1], route[j + 1], adjacency_matrix)

                # If the new distance is less, perform the swap and mark that we improved the route
                if new_distance < current_distance:
                    # Perform the swap: reverse the segment between i+1 and j
                    route[i + 1:j + 1] = route[i + 1:j + 1][::-1]
                    improved = True

    return route



def calculer_cout(route, matrice_distances):
    """Calculates the total travel cost of a given route using the distance matrix."""
    cout_total = 0
    for i in range(len(route) - 1):
        # Get the distance between the current city and the next city
        distance = matrice_distances[route[i]][route[i + 1]]
        cout_total += distance
    # Add the distance to return to the starting city
    cout_total += matrice_distances[route[-1]][route[0]]
    return cout_total


# Fonction pour générer une solution initiale
def generer_solution_initiale(nb_villes):
    # Crée une liste des villes à partir de 1 à nb_villes-1 car 0 est déjà inclus comme point de départ
    villes = list(range(0, nb_villes))
    random.shuffle(villes)
    # Ajoute 0 au début et à la fin pour fermer le circuit
    return [0] + villes + [0]

# Fonction pour générer un voisinage (2-opt swap)
def generer_voisinage(S):
    voisinage = []
    for i in range(1, len(S)):
        for j in range(i, len(S)):
            voisin = S[:]
            voisin[i:j] = voisin[i:j][::-1]
            voisinage.append(voisin)
    return voisinage

def hybrid_tabu_search(G, nb_villes, matrice_distances, nb_iterations_max, taille_liste_tabou, max_iter_sans_amelioration, seuil_variance):
    meilleure_solution, meilleur_cout = christofides_algorithm(G)
    #meilleure_solution = recherche_locale_2opt(matrice_distances, meilleure_solution)

    liste_tabou = []
    iter_sans_amelioration = 0
    var_couts = []

    for iteration in range(nb_iterations_max):
        if iter_sans_amelioration >= max_iter_sans_amelioration:  # Critère d'arrêt
            break

        voisinage = generer_voisinage(meilleure_solution)
        for voisin in voisinage:
            cout_voisin = calculer_cout(voisin, matrice_distances)
            if cout_voisin < meilleur_cout and (voisin not in liste_tabou):
                meilleure_solution = voisin
                meilleur_cout = cout_voisin
                iter_sans_amelioration = 0  # Réinitialiser le compteur
                var_couts.append(meilleur_cout)
                break  # Sortie précoce pour intensification
        else:
            iter_sans_amelioration += 1  # Incrémente si aucune amélioration n'est trouvée dans ce cycle

        # Diversification et Intensification
        if iteration % 100 == 0 and iteration != 0:
            if random.random() < 0.5:  # Diversification
                meilleure_solution = generer_solution_initiale(nb_villes)
                meilleur_cout = calculer_cout(meilleure_solution, matrice_distances)
            else:  # Intensification
                meilleure_solution = recherche_locale_2opt(meilleure_solution, matrice_distances)
                meilleur_cout = calculer_cout(meilleure_solution, matrice_distances)


        liste_tabou.append(meilleure_solution.copy())
        if len(liste_tabou) > taille_liste_tabou:
            liste_tabou.pop(0)

        if len(var_couts) > 10:
            variance = np.var(var_couts[-10:])
            if variance < seuil_variance:
                break

    return meilleure_solution, meilleur_cout


nb_villes = 53
# Création du graphe
G = build_graph_from_distance_matrix(matrice_distances)


# Paramètres pour la recherche taboue
nb_iterations_max = 100
taille_liste_tabou = 15
max_iter_sans_amelioration = 20
seuil_variance = 1e-4

# Exécution de l'algorithme hybride
solution, cout = hybrid_tabu_search(G, nb_villes, matrice_distances, nb_iterations_max, taille_liste_tabou, max_iter_sans_amelioration, seuil_variance)

print("Solution finale:", solution)
print("Coût de la solution:", calculer_cout(solution, matrice_distances))
# Out:
# Solution finale: [0, 39, 43, 42, 45, 16, 22, 2, 29, 17, 24, 1, 3, 30, 8, 4, 12, 9, 10, 11, 15, 26, 19, 31, 25, 20, 7, 13, 23, 40, 32, 6, 21, 33, 38, 46, 35, 14, 28, 5, 27, 47, 34, 18, 37, 41, 44, 36, 0]
# Coût de la solution: 5273.0

# %%
import networkx as nx
import numpy as np
import random
import time
from networkx.algorithms.matching import min_weight_matching
import networkx as nx
import numpy as np
import random
import time
from networkx.algorithms.matching import min_weight_matching




def build_graph_from_distance_matrix(distance_matrix):
    G = nx.Graph()
    for i in range(len(distance_matrix)):
        for j in range(i + 1, len(distance_matrix)):
            G.add_edge(i, j, weight=distance_matrix[i][j])
    return G
# Vous devriez avoir les fonctions calculer_cout, generer_solution_initiale, generer_voisinage, christofides_algorithm déjà définies comme dans votre code précédent.
def calculate_distance(city1, city2, adjacency_matrix):
    """Calculates the distance between two cities using the adjacency matrix."""
    if isinstance(city1, int) and isinstance(city2, int):
        return adjacency_matrix[city1][city2]


def recherche_locale_2opt(adjacency_matrix, route):
    """Performs the 2-opt algorithm to improve a given route. Assumes route and adjacency_matrix are properly formatted."""
    # Ensure that all route indices are integers
    route = [int(r) for r in route]

    improved = True
    while improved:
        improved = False
        for i in range(1, len(route) - 2):
            for j in range(i + 2, len(route) - 1):  # Assure that we have at least one element between i and j
                # Calculate the current distances between i and i+1, and j and j+1
                current_distance = adjacency_matrix[route[i]][route[i + 1]] + \
                                   adjacency_matrix[route[j]][route[j + 1]]

                # Calculate what the distance would be if we swapped i+1 and j
                new_distance = adjacency_matrix[route[i]][route[j]] + \
                               adjacency_matrix[route[i + 1]][route[j + 1]]

                # If the new distance is less, perform the swap and mark that we improved the route
                if new_distance < current_distance:
                    # Perform the swap: reverse the segment between i+1 and j
                    route[i + 1:j + 1] = route[i + 1:j + 1][::-1]
                    improved = True

    return route



def calculer_cout(route, matrice_distances):
    """Calculates the total travel cost of a given route using the distance matrix."""
    cout_total = 0
    for i in range(len(route) - 1):
        # Get the distance between the current city and the next city
        distance = matrice_distances[route[i]][route[i + 1]]
        cout_total += distance
    # Add the distance to return to the starting city
    cout_total += matrice_distances[route[-1]][route[0]]
    return cout_total


# Fonction pour générer une solution initiale
def generer_solution_initiale(nb_villes):
    # Crée une liste des villes à partir de 1 à nb_villes-1 car 0 est déjà inclus comme point de départ
    villes = list(range(0, nb_villes))
    random.shuffle(villes)
    # Ajoute 0 au début et à la fin pour fermer le circuit
    return  villes

# Fonction pour générer un voisinage (2-opt swap)
def generer_voisinage(S):
    voisinage = []
    for i in range(1, len(S)):
        for j in range(i, len(S)):
            voisin = S[:]
            voisin[i:j] = voisin[i:j][::-1]
            voisinage.append(voisin)
    return voisinage





def christofides_algorithm(G):
    # Trouver un arbre couvrant minimal
    T = nx.minimum_spanning_tree(G, weight='weight')

    # Trouver les sommets de degré impair dans l'arbre couvrant minimal
    odd_degree_nodes = [node for node in T.nodes() if T.degree(node) % 2 == 1]

    # Restreindre le graphe aux sommets de degré impair
    odd_graph = G.subgraph(odd_degree_nodes)

    # Trouver un matching parfait de poids minimum dans le graphe restreint
    matching = min_weight_matching(odd_graph)

    # Ajouter le matching à l'arbre couvrant minimal pour obtenir un multigraphe
    multigraph = nx.MultiGraph(T)
    for edge in matching:
        multigraph.add_edge(edge[0], edge[1], weight=G[edge[0]][edge[1]]['weight'])

    # Trouver un circuit Eulerien dans le multigraphe
    eulerian_circuit = list(nx.eulerian_circuit(multigraph))

    # Convertir le circuit Eulerien en un circuit Hamiltonien et calculer le coût
    visited = set()
    hamiltonian_circuit = []
    total_cost = 0
    last_node = None
    #print(eulerian_circuit)
    for u, v in eulerian_circuit:
        if u not in visited:
            if last_node is not None:
                total_cost += G[last_node][u]['weight']
            visited.add(u)
            hamiltonian_circuit.append(u)
            last_node = u
        if v not in visited:
            if last_node is not None:
                total_cost += G[last_node][v]['weight']
            visited.add(v)
            hamiltonian_circuit.append(v)
            last_node = v
    # Ajouter le coût pour retourner au point de départ
    # Ajouter le coût pour retourner au point de départ pour former un cycle
    if hamiltonian_circuit:
        start_node = hamiltonian_circuit[0]
        end_node = hamiltonian_circuit[-1]
        if start_node != end_node:
            hamiltonian_circuit.append(start_node)
            total_cost += G[end_node][start_node]['weight']

    return hamiltonian_circuit, total_cost


# Fonction pour générer une solution initiale
def generer_solution_initiale(nb_villes):
    return random.sample(range(nb_villes), nb_villes)



# Algorithme de recherche tabou avec intensification, diversification et critère d'aspiration
def recherche_tabou(G,nb_villes, nb_iterations_max, taille_liste_tabou, matrice_distances, diversifier, intensifier, stop_stagnation, max_iter_sans_amelioration, initialize_randomly,seuil_variance):
    # Initialisation
    if initialize_randomly:
      S = generer_solution_initiale(nb_villes)
      meilleur_cout = calculer_cout(S, matrice_distances)
    else:
     S, meilleur_cout = christofides_algorithm(G) # Christofides
     S = recherche_locale_2opt(adjacency_matrix=matrice_distances ,route=S)

    meilleure_solution = S[:]
    liste_tabou = []
    iter_sans_amelioration = 0
    var_couts = []

    # Boucle principale
    for iteration in range(nb_iterations_max):
        voisinage = generer_voisinage(S)
        S_prime, cout_S_prime = None, float('inf')

        # Recherche d'une meilleure solution dans le voisinage
        for voisin in voisinage:
            cout_voisin = calculer_cout(voisin, matrice_distances)
            if (cout_voisin < cout_S_prime and
                (voisin not in liste_tabou or cout_voisin < meilleur_cout)):
                S_prime = voisin
                cout_S_prime = cout_voisin


        # Mise à jour de la meilleure solution trouvée
        if S_prime and cout_S_prime < meilleur_cout:
            meilleure_solution = S_prime[:]
            meilleur_cout = cout_S_prime

            if stop_stagnation:
              #print(iter_sans_amelioration)
              iter_sans_amelioration = 0  # Réinitialisation du compteur d'itérations sans amélioration
            var_couts.append(cout_S_prime)
        else:
            if stop_stagnation:
              iter_sans_amelioration += 1  # Incrémenter le compteur

        # Mise à jour de la solution actuelle et de la liste tabou
        S = S_prime or S
        liste_tabou.append(S)
        if len(liste_tabou) > taille_liste_tabou:
            liste_tabou.pop(0)

        # Intensification: Revenir à la meilleure solution périodiquement
       # Diversification et Intensification
        if iteration % 100 == 0 and iteration != 0:
            if (random.random() > 0.5):  # Diversification
              if diversifier:
                S= generer_solution_initiale(nb_villes)
            else:  # Intensification
               if intensifier:
                 if (random.random() > 0.5):
                    print(S_prime)
                    S = recherche_locale_2opt(adjacency_matrix=matrice_distances ,route=S_prime)
                 else :
                    S = generer_solution_initiale(nb_villes)
                    liste_tabou = []


        # Stop si stagnation
        if stop_stagnation:
          if iter_sans_amelioration >= max_iter_sans_amelioration:
              print(f"Stagnation atteinte à l'itération {iteration}, arrêt prématuré.")
              break

        # Variation de la taille de la liste tabou
        taille_liste_tabou = 10 if iteration % 15 == 0 else 15

        print(f"Iteration {iteration}: Cout actuel = {cout_S_prime}, Meilleur cout = {meilleur_cout}")

        if len(var_couts) > 10:
            variance = np.var(var_couts[-10:])
            if variance < seuil_variance:
                break

    return meilleure_solution, meilleur_cout
G=build_graph_from_distance_matrix(matrice_distances)
# Paramètres de l'algorithme
nb_villes = 262 # Nombre de villes
nb_iterations_max = 1000  # Nombre d'itérations maximal
taille_liste_tabou_initiale = 20  # Taille initiale de la liste tabou
diversifier = True
intensifier = True
stop_stagnation = True
max_iter_sans_amelioration =30
initialize_randomly = False
seuil_variance = 1e-4
start_time = time.time()
# Exécution de l'algorithme de recherche tabou
meilleure_solution, cout_meilleure_solution = recherche_tabou(G,nb_villes, nb_iterations_max, taille_liste_tabou_initiale, matrice_distances, diversifier, intensifier, stop_stagnation, 30, initialize_randomly,seuil_variance)



end_time = time.time()
elapsed_time = end_time - start_time
print(cout_meilleure_solution)

print(f"Elapsed Time: {elapsed_time} seconds")
# Out:
# Iteration 0: Cout actuel = 2481.998156924036, Meilleur cout = 2481.998156924036
# Iteration 1: Cout actuel = 2481.9981569240376, Meilleur cout = 2481.998156924036
# Iteration 2: Cout actuel = 2482.0341914069318, Meilleur cout = 2481.998156924036
# Iteration 3: Cout actuel = 2481.580695961236, Meilleur cout = 2481.580695961236
# Iteration 4: Cout actuel = 2481.5806959612346, Meilleur cout = 2481.5806959612346
# Iteration 5: Cout actuel = 2481.635763998886, Meilleur cout = 2481.5806959612346
# Iteration 6: Cout actuel = 2472.150763110309, Meilleur cout = 2472.150763110309
# Iteration 7: Cout actuel = 2472.150763110311, Meilleur cout = 2472.150763110309
# Iteration 8: Cout actuel = 2472.304673951004, Meilleur cout = 2472.150763110309
# Iteration 9: Cout actuel = 2472.304673951003, Meilleur cout = 2472.150763110309
# Iteration 10: Cout actuel = 2472.52416324401, Meilleur cout = 2472.150763110309
# Iteration 11: Cout actuel = 2472.3702524033165, Meilleur cout = 2472.150763110309
# Iteration 12: Cout actuel = 2472.3702524033174, Meilleur cout = 2472.150763110309
# Iteration 13: Cout actuel = 2472.5241632440116, Meilleur cout = 2472.150763110309
# Iteration 14: Cout actuel = 2472.7647739712374, Meilleur cout = 2472.150763110309
# Iteration 15: Cout actuel = 2472.2398751430246, Meilleur cout = 2472.150763110309
# Iteration 16: Cout actuel = 2472.020385850017, Meilleur cout = 2472.020385850017
# Iteration 17: Cout actuel = 2471.8664750093235, Meilleur cout = 2471.8664750093235
# Iteration 18: Cout actuel = 2471.8664750093217, Meilleur cout = 2471.8664750093217
# Iteration 19: Cout actuel = 2472.020385850016, Meilleur cout = 2471.8664750093217
# Iteration 20: Cout actuel = 2472.239875143023, Meilleur cout = 2471.8664750093217
# Iteration 21: Cout actuel = 2472.085964302329, Meilleur cout = 2471.8664750093217
# Iteration 22: Cout actuel = 2472.0859643023305, Meilleur cout = 2471.8664750093217
# Iteration 23: Cout actuel = 2472.3885910448466, Meilleur cout = 2471.8664750093217
# Iteration 24: Cout actuel = 2472.1691017518397, Meilleur cout = 2471.8664750093217
# Iteration 25: Cout actuel = 2472.169101751838, Meilleur cout = 2471.8664750093217
# Iteration 26: Cout actuel = 2472.323012592532, Meilleur cout = 2471.8664750093217
# Iteration 27: Cout actuel = 2472.3230125925334, Meilleur cout = 2471.8664750093217
# Iteration 28: Cout actuel = 2472.542501885541, Meilleur cout = 2471.8664750093217
# Iteration 29: Cout actuel = 2472.542501885539, Meilleur cout = 2471.8664750093217
# Iteration 30: Cout actuel = 2472.3885910448453, Meilleur cout = 2471.8664750093217
# Iteration 31: Cout actuel = 2472.729542492727, Meilleur cout = 2471.8664750093217
# Iteration 32: Cout actuel = 2472.5100531997196, Meilleur cout = 2471.8664750093217
# Iteration 33: Cout actuel = 2472.5100531997214, Meilleur cout = 2471.8664750093217
# Iteration 34: Cout actuel = 2472.6639640404155, Meilleur cout = 2471.8664750093217
# Iteration 35: Cout actuel = 2472.6639640404137, Meilleur cout = 2471.8664750093217
# Iteration 36: Cout actuel = 2472.8834533334207, Meilleur cout = 2471.8664750093217
# Iteration 37: Cout actuel = 2472.8834533334225, Meilleur cout = 2471.8664750093217
# Iteration 38: Cout actuel = 2472.729542492729, Meilleur cout = 2471.8664750093217
# Iteration 39: Cout actuel = 2472.3885910448466, Meilleur cout = 2471.8664750093217
# Iteration 40: Cout actuel = 2472.0859643023305, Meilleur cout = 2471.8664750093217
# Iteration 41: Cout actuel = 2471.8664750093235, Meilleur cout = 2471.8664750093217
# Iteration 42: Cout actuel = 2471.8664750093217, Meilleur cout = 2471.8664750093217
# Iteration 43: Cout actuel = 2472.020385850016, Meilleur cout = 2471.8664750093217
# Iteration 44: Cout actuel = 2472.020385850017, Meilleur cout = 2471.8664750093217
# Iteration 45: Cout actuel = 2472.2398751430246, Meilleur cout = 2471.8664750093217
# Iteration 46: Cout actuel = 2472.239875143023, Meilleur cout = 2471.8664750093217
# Iteration 47: Cout actuel = 2472.085964302329, Meilleur cout = 2471.8664750093217
# Stagnation atteinte à l'itération 48, arrêt prématuré.
# 2471.8664750093217
# Elapsed Time: 89.62705111503601 seconds

# %%
import networkx as nx
import numpy as np
import random
import time
from networkx.algorithms.matching import min_weight_matching

def build_graph_from_distance_matrix(distance_matrix):
    G = nx.Graph()
    for i in range(len(distance_matrix)):
        for j in range(i + 1, len(distance_matrix)):
            G.add_edge(i, j, weight=distance_matrix[i][j])
    return G
def christofides_algorithm(G):
    # Trouver un arbre couvrant minimal
    T = nx.minimum_spanning_tree(G, weight='weight')

    # Trouver les sommets de degré impair dans l'arbre couvrant minimal
    odd_degree_nodes = [node for node in T.nodes() if T.degree(node) % 2 == 1]

    # Restreindre le graphe aux sommets de degré impair
    odd_graph = G.subgraph(odd_degree_nodes)

    # Trouver un matching parfait de poids minimum dans le graphe restreint
    matching = min_weight_matching(odd_graph)

    # Ajouter le matching à l'arbre couvrant minimal pour obtenir un multigraphe
    multigraph = nx.MultiGraph(T)
    for edge in matching:
        multigraph.add_edge(edge[0], edge[1], weight=G[edge[0]][edge[1]]['weight'])

    # Trouver un circuit Eulerien dans le multigraphe
    eulerian_circuit = list(nx.eulerian_circuit(multigraph))

    # Convertir le circuit Eulerien en un circuit Hamiltonien et calculer le coût
    visited = set()
    hamiltonian_circuit = []
    total_cost = 0
    last_node = None
    #print(eulerian_circuit)
    for u, v in eulerian_circuit:
        if u not in visited:
            if last_node is not None:
                total_cost += G[last_node][u]['weight']
            visited.add(u)
            hamiltonian_circuit.append(u)
            last_node = u
        if v not in visited:
            if last_node is not None:
                total_cost += G[last_node][v]['weight']
            visited.add(v)
            hamiltonian_circuit.append(v)
            last_node = v
    # Ajouter le coût pour retourner au point de départ
    # Ajouter le coût pour retourner au point de départ pour former un cycle
    if hamiltonian_circuit:
        start_node = hamiltonian_circuit[0]
        end_node = hamiltonian_circuit[-1]
        if start_node != end_node:
            hamiltonian_circuit.append(start_node)
            total_cost += G[end_node][start_node]['weight']

    return hamiltonian_circuit, total_cost
# Fonction pour calculer le coût d'une solution
def calculer_cout(S, matrice_distances):
    cout = 0
    n = len(S)
    for i in range(n):
        cout += matrice_distances[S[i]][S[(i + 1) % n]]  # Distance entre la ville i et i+1
    return cout

# Fonction pour générer une solution initiale
def generer_solution_initiale(nb_villes):
    return random.sample(range(nb_villes), nb_villes)

# Fonction pour générer un voisinage (2-opt swap)
def generer_voisinage(S):
    voisinage = []
    for i in range(1, len(S) - 1):
        for j in range(i + 1, len(S)):
            voisin = S[:]
            voisin[i:j] = voisin[i:j][::-1]
            voisinage.append(voisin)
    return voisinage

# Algorithme de recherche tabou avec intensification, diversification et critère d'aspiration
def recherche_tabou(G,nb_villes, nb_iterations_max, taille_liste_tabou, matrice_distances, diversifier, intensifier, stop_stagnation, max_iter_sans_amelioration, initialize_randomly):
    # Initialisation
    if initialize_randomly:
      S = generer_solution_initiale(nb_villes)
      meilleur_cout = calculer_cout(S, matrice_distances)
    else:
     S, meilleur_cout = christofides_algorithm(G) # Christofides
    meilleure_solution = S[:]
    liste_tabou = []
    iter_sans_amelioration = 0

    # Boucle principale
    for iteration in range(nb_iterations_max):
        voisinage = generer_voisinage(S)
        S_prime, cout_S_prime = None, float('inf')

        # Recherche d'une meilleure solution dans le voisinage
        for voisin in voisinage:
            cout_voisin = calculer_cout(voisin, matrice_distances)
            if (cout_voisin < cout_S_prime and
                (voisin not in liste_tabou or cout_voisin < meilleur_cout)):
                S_prime = voisin
                cout_S_prime = cout_voisin

        # Mise à jour de la meilleure solution trouvée
        if S_prime and cout_S_prime < meilleur_cout:
            meilleure_solution = S_prime[:]
            meilleur_cout = cout_S_prime
            if stop_stagnation:
              iter_sans_amelioration = 0  # Réinitialisation du compteur d'itérations sans amélioration
        else:
            if stop_stagnation:
              iter_sans_amelioration += 1  # Incrémenter le compteur

        # Mise à jour de la solution actuelle et de la liste tabou
        S = S_prime or S
        liste_tabou.append(S)
        if len(liste_tabou) > taille_liste_tabou:
            liste_tabou.pop(0)

        # Intensification: Revenir à la meilleure solution périodiquement
        if intensifier:
          if iteration % 100 == 0 and iteration != 0:
              S = meilleure_solution

        # Diversification: Relancer avec une nouvelle solution initiale si stagnation
        if diversifier:
          if iteration % 200 == 0 and iteration != 0:
              S = generer_solution_initiale(nb_villes)
              liste_tabou = []  # Réinitialiser la liste tabou après la diversification

        # Stop si stagnation
        if stop_stagnation:
          if iter_sans_amelioration >= max_iter_sans_amelioration:
              print(f"Stagnation atteinte à l'itération {iteration}, arrêt prématuré.")
              break

        # Variation de la taille de la liste tabou
        taille_liste_tabou = 10 if iteration % 15 == 0 else 15

        print(f"Iteration {iteration}: Cout actuel = {cout_S_prime}, Meilleur cout = {meilleur_cout}")

    return meilleure_solution, meilleur_cout
G=build_graph_from_distance_matrix(matrice_distances)
# Paramètres de l'algorithme
nb_villes = 24  # Nombre de villes
nb_iterations_max = 1000  # Nombre d'itérations maximal
taille_liste_tabou_initiale = 20  # Taille initiale de la liste tabou
diversifier = True
intensifier = True
stop_stagnation = False
max_iter_sans_amelioration =30
initialize_randomly = False
# Exécution de l'algorithme de recherche tabou
meilleure_solution, cout_meilleure_solution = recherche_tabou(G,nb_villes, nb_iterations_max, taille_liste_tabou_initiale, matrice_distances, diversifier, intensifier, stop_stagnation, 30, initialize_randomly)
